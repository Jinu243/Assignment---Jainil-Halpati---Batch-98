# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# %%
os.chdir("C:\\Users\\USER\\Downloads\\Batch 98 Day 26\\CS 17 Ans -Data Transformation-3\\")

# %%
print(os.getcwd())
# Out:
# C:\Users\USER\Downloads\Batch 98 Day 26\CS 17 Ans -Data Transformation-3

# %% [markdown]
# 1.	You are given a dataset, containing the number of hurricanes (Hurricanes.csv) occurring in the United States along the coast of the Atlantic. Load the data from the dataset into your program and plot a Bar Graph of the data, taking the Year as the x-axis and the number of hurricanes occurring as the Y-axis.

# %%
df = pd.read_csv('Hurricanes.csv',delimiter=',')

# %%
df.head()
# Out:
#    Year  Hurricanes
# 0  1914           0
# 1  1915           5
# 2  1916          10
# 3  1917           2
# 4  1918           4

# %%
plt.rcParams['figure.figsize'] = (20,10)
plt.bar(df['Year'],df['Hurricanes'])
plt.show()

# %% [markdown]
# 2.	The dataset given, records data of city temperatures over the years’ 2014 and 2015. Plot the histogram of the temperatures over this period for the cities of San Francisco and Moscow.

# %%
df1 = pd.read_csv('CityTemps.csv',delimiter = ',')

# %%
df1.head()
# Out:
#    Year  Month  Moscow  Melbourne  San Francisco
# 0  2014      1    -8.6       22.0           12.8
# 1  2014      2    -1.9       21.5           12.7
# 2  2014      3     2.8       19.5           15.0
# 3  2014      4     7.0       15.8           15.7
# 4  2014      5    16.0       13.9           17.5

# %%
plt.hist([df1['San Francisco'], df1['Moscow']], bins=[-10,-5,0,5,10,15,20], rwidth=1, label=['SF','Moscow'])
plt.legend()
plt.show()

# %% [markdown]
# 3.1 Load the Data set sample-salesv2.csv , then display top 5 records

# %%
df2 = pd.read_csv('sample-salesv2.csv',parse_dates=['date'])

# %%
df2.head()
# Out:
#    account_number       name item_code category  quantity  unit price  \
# 0          734922  Berge LLC  QN-82852     Belt         4       57.75
# 1          734922  Berge LLC  GS-86623    Shoes         3       99.88
# 2          734922  Berge LLC  LW-86841    Shoes         5       56.00
# 3          734922  Berge LLC  GS-86623    Shoes        19       28.54
# 4          734922  Berge LLC  MJ-21460    Shoes        12       53.70
#
#    net_price              date
# 0     231.00  04-11-2013 09:48
# 1     299.64  04-08-2014 23:08
# 2     280.00  22-11-2013 17:45
# 3     542.26  26-10-2013 17:03
# 4     644.40  27-09-2014 02:51

# %% [markdown]
# 3.2 Use the Describe statement and describe the column – Unit Price

# %%
df2['unit price'].describe()
# Out:
# count    1000.000000
# mean       56.179630
# std        25.331939
# min        10.060000
# 25%        35.995000
# 50%        56.765000
# 75%        76.802500
# max        99.970000
# Name: unit price, dtype: float64

# %% [markdown]
# 3.3 Extract the columns / create  a data frame customers , with columns Name, Net_price . Do the group by based on column name.

# %%
coustomers = df2[['name','net_price','date']]

# %%
coustomers.head()
# Out:
#         name  net_price              date
# 0  Berge LLC     231.00  04-11-2013 09:48
# 1  Berge LLC     299.64  04-08-2014 23:08
# 2  Berge LLC     280.00  22-11-2013 17:45
# 3  Berge LLC     542.26  26-10-2013 17:03
# 4  Berge LLC     644.40  27-09-2014 02:51

# %%
coustomers_group = coustomers.groupby('name')

# %%
coustomers_group.size()
# Out:
# name
# Berge LLC                        52
# Carroll PLC                      57
# Cole-Eichmann                    51
# Davis, Kshlerin and Reilly       41
# Ernser, Cruickshank and Lind     47
# Gorczany-Hahn                    42
# Hamill-Hackett                   44
# Hegmann and Sons                 58
# Heidenreich-Bosco                40
# Huel-Haag                        43
# Kerluke, Reilly and Bechtelar    52
# Kihn, McClure and Denesik        58
# Kilback-Gerlach                  45
# Koelpin PLC                      53
# Kunze Inc                        54
# Kuphal, Zieme and Kub            52
# Senger, Upton and Breitenberg    59
# Volkman, Goyette and Lemke       48
# Waelchi-Fahey                    54
# Waters-Walker                    50
# dtype: int64

# %% [markdown]
# 3.4 – Create bar graph, customer by Sales ( x- axis – Customer , y-axis – Sales)

# %%
sales_total = coustomers_group.sum()

# %%
plot = sales_total.plot(kind='bar')
plt.show()

# %% [markdown]
# 4.	Let the x axis data points and y axis data points are
#
# X = [1,2,3,4]
#
# y = [20, 21, 20.5, 20.8]

# %%
x = [1,2,3,4]
y = [20,21,20.5,20.8]

# %% [markdown]
# 4.1: Draw a Simple plot

# %%
plt.plot(x,y)
plt.show()

# %% [markdown]
# 4.2: Configure the line and markers in simple plot

# %%
plt.plot(x,y,linestyle='dashed',marker='o',color='green')
plt.show()

# %% [markdown]
# 4.3: configure the axes

# %%
plt.plot(x,y,linestyle='dashed',marker='o',color='green')
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])
plt.ylim(19.5,21.5)
plt.yticks([20,21,20.5,20.8])
plt.show()

# %% [markdown]
# 4.4: Give title of Graph & labels of x axis and y axis

# %%
plt.plot(x,y,linestyle='dashed',marker='o',color='green')
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])
plt.ylim(19.5,21.5)
plt.yticks([20,21,20.5,20.8])
plt.xlabel('This is X')
plt.ylabel('This is Y')
plt.title('Simple Plot')
plt.show()

# %% [markdown]
# 4.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]

# %%
y_error = [0.12,0.13,0.2,0.1]

# %%
plt.plot(x,y,linestyle='dashed',marker='o',color='green')
plt.errorbar(x, y, yerr=y_error, linestyle="None", marker="None", color="blue")
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])
plt.ylim(19.5,21.5)
plt.yticks([20,21,20.5,20.8])
plt.xlabel('This is X')
plt.ylabel('This is Y')
plt.title('Simple Plot')
plt.show()

# %% [markdown]
# 4.6: define width, height as figsize=(4,5) DPI and adjust plot dpi=100

# %%
fig = plt.figure(figsize=(4,5),dpi=100)
plt.plot(x,y,linestyle='dashed',marker='o',color='green')
plt.errorbar(x, y, yerr=y_error, linestyle="None", marker="None", color="blue")
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])
plt.ylim(19.5,21.5)
plt.yticks([20,21,20.5,20.8])
plt.xlabel('This is X')
plt.ylabel('This is Y')
plt.title('Simple Plot')
plt.show()

# %% [markdown]
# 4.7: Give a font size of 14

# %%
fig = plt.figure(figsize=(4,5),dpi=100)
plt.rc('font',size=14)
plt.plot(x,y,linestyle='dashed',marker='o',color='green')
plt.errorbar(x,y,yerr=y_error,linestyle='None',marker='None',color='blue')
plt.xlim(0.5,4.5)
plt.xticks([1,2,3,4])
plt.ylim(19.5,21.5)
plt.yticks([20,21,20.5,20.8])
plt.xlabel('This is X')
plt.ylabel('This is Y')
plt.title('Simple Plot')
plt.show()

# %% [markdown]
# 4.8: Draw a scatter graph of any 50 random values of x and y axis

# %%
N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2
plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %% [markdown]
# 4.9: Create a dataframe from following data
#
#
# 'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
#
# 'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
#
# 'female': [0, 1, 1, 0, 1],
#
# 'age': [42, 52, 36, 24, 73],
#
# 'preTestScore': [4, 24, 31, 2, 3],
#
# 'postTestScore': [25, 94, 57, 62, 70]
#
#
# Draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age

# %%
raw_data = {'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
        'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
        'female': [0, 1, 1, 0, 1],
        'age': [42, 52, 36, 24, 73],
        'preTestScore': [4, 24, 31, 2, 3],
        'postTestScore': [25, 94, 57, 62, 70]}

df = pd.DataFrame(raw_data, columns = ['first_name', 'last_name', 'age', 'female', 'preTestScore', 'postTestScore'])

print(df.head())
# Out:
#   first_name last_name  age  female  preTestScore  postTestScore
# 0      Jason    Miller   42       0             4             25
# 1      Molly  Jacobson   52       1            24             94
# 2       Tina       Ali   36       1            31             57
# 3       Jake    Milner   24       0             2             62
# 4        Amy     Cooze   73       1             3             70

# %%
plt.scatter(df.preTestScore,df.postTestScore,s=df.age)

# %% [markdown]
# 4.10: Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and the color determined by sex

# %%
plt.scatter(df.preTestScore,df.postTestScore,s=300,c=df.female)
